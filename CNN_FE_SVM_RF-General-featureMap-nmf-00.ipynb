# %% [markdown]
# <a href="https://colab.research.google.com/github/HazenDeveloper/Attn-CNN-Model/blob/main/CNN_FE_SVM_RF-General-featureMap-nmf-00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install imutils
import keras
import tensorflow as tf

import os
from keras.layers import Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import Input
from keras.layers import BatchNormalization
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
from keras.models import Model
from sklearn.utils import shuffle
from cv2 import imread
import numpy as np
import pandas as pd

# %%
from pandas.core.api import unique
from os import listdir, walk
from os.path import isfile, join
import cv2
from google.colab.patches import cv2_imshow
from imutils import paths

path = list(paths.list_images('/content/drive/MyDrive/ML-Datasets/Retinopathy/Messidor_dataset_without_clahe'))
labs = [i.split(os.path.sep)[-2] for i in path]

print(labs)
# print('testing', imagePaths[1].split(os.path.sep)[-2])

# img = cv2.imread(imagePaths[2])
# cv2_imshow(img)
# Out:
# ['normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', ...

# %%
width,height=256,256
depth = 3
input_shape = (height, width, depth)

classes = 4

imagePaths = list(paths.list_images('/content/drive/MyDrive/ML-Datasets/Retinopathy/Messidor_dataset_without_clahe'))

# train_data_dir = '/content/drive/MyDrive/ML-Datasets/LungsCancer/Normal'
# test_data_dir = '/content/drive/MyDrive/ML-Datasets/LungsCancer/Bengin'
# valid_data_dir = '/content/drive/MyDrive/ML-Datasets/LungsCancer/Malignant'

data = []
labels = []

for imagePath in imagePaths:
    label = imagePath.split(os.path.sep)[-2]
    image = load_img(imagePath, target_size=(width, height))
    image = img_to_array(image)
    data.append(image)
    labels.append(label)

data = np.array(data, dtype="float32")
labels = np.array(labels)
print(len(data), len(labels))

from sklearn.preprocessing import  LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# le = LabelEncoder()
# labels = le.fit_transform(labels)

# ohe = OneHotEncoder()
# labels = ohe.fit_transform(labels)

lb = LabelBinarizer()
labels = lb.fit_transform(labels)

#labels = to_categorical(labels)

data, labels = shuffle(data, labels)

print(data.shape)
print(labels.shape)
# Out:
# 1200 1200
# (1200, 256, 256, 3)
# (1200, 4)

# %%
test_ratio = 0.2
# train is now 75% of the entire data set
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=test_ratio, stratify=labels)

print("Train images:",x_train.shape)
print("Test images:",x_test.shape)
print("Train label:",y_train.shape)
print("Test label:",y_test.shape)
# Out:
# Train images: (960, 256, 256, 3)
# Test images: (240, 256, 256, 3)
# Train label: (960, 4)
# Test label: (240, 4)

# %%
xx_train, x_valid, yy_train, y_valid = train_test_split(x_train, y_train,test_size=test_ratio)

# %%
print("Train images:",x_train.shape)
print("Test images:",x_valid.shape)
print("Train label:",y_train.shape)
print("Test label:",y_valid.shape)
# Out:
# Train images: (768, 256, 256, 3)
# Test images: (192, 256, 256, 3)
# Train label: (768, 4)
# Test label: (192, 4)

# %%
(x_train.shape[0])
# Out:
# 768

# %%
def MiniVGGNet(width, heigth, depth, classes):
	model = Sequential()
	input_shape = (heigth, width, depth)
	chanDim = -1

	if keras.backend.image_data_format() == "channel_first":
		input_shape = (depth, heigth, width)
		chanDim = 1

	model.add(Conv2D(8,(3,3), padding="same", input_shape=input_shape, activation="relu"))
	# model.add(BatchNormalization(axis=chanDim))
	# model.add(Conv2D(32,(3,3), padding="same", input_shape=input_shape, activation="relu"))
	# model.add(BatchNormalization(axis=chanDim))
	model.add(MaxPooling2D(pool_size=(2,2), strides=2))
	# model.add(Dropout(0.25))

	# model.add(Conv2D(64,(3,3), padding="same", input_shape=input_shape, activation="relu"))
	# model.add(BatchNormalization(axis=chanDim))
	model.add(Conv2D(16,(3,3), padding="same", activation="relu"))
	# model.add(BatchNormalization(axis=chanDim))
	model.add(MaxPooling2D(pool_size=(2,2),strides=2))
	model.add(Dropout(0.25))

	model.add(Conv2D(32,(3,3), padding="same", activation="relu"))
	# model.add(BatchNormalization(axis=chanDim))
	model.add(MaxPooling2D(pool_size=(2,2), strides=2))
	# model.add(Dropout(0.25))

	model.add(Conv2D(64,(3,3), padding="same", activation="relu"))
	# model.add(BatchNormalization(axis=chanDim))
	model.add(MaxPooling2D(pool_size=(2,2), strides=2))
	model.add(Dropout(0.25))


	model.add(BatchNormalization())
	model.add(Flatten())
	model.add(Dense(4096))
	# model.add(Dense(1024))
	model.add(Dense(1024, activation="relu"))
	# model.add(BatchNormalization())
	model.add(Dropout(0.5))
	model.add(Dense(classes, activation="softmax"))

	return model

# %%
#!pip install scikit-plot
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np
# import scikitplot as skplt
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn import metrics
import tensorflow

# cnn_model = tensorflow.keras.models.load_model('best_model.h5')
# x_test = test_generator
# x_train = train_generator
# y_test = test_generator.classes
def plot_results(h):
  # plot the training loss and accuracy
  N = len(h.epoch)
  plt.style.use("ggplot")
  plt.figure()
  plt.plot(np.arange(0, N), h.history["loss"], label="train_loss")
  # plt.plot(np.arange(0, N), h.history["val_loss"], label="val_loss")
  # plt.title("Training Loss vs. validation Loss")
  # plt.xlabel("Epoch #")
  # plt.ylabel("Loss")
  # plt.legend(loc="lower left")
  # plt.show()

  # plt.figure()
  plt.plot(np.arange(0, N), h.history["accuracy"], label="train_acc")
  # plt.plot(np.arange(0, N), h.history["val_accuracy"], label="val_acc")
  # plt.title("Training Accuracy vs. Validation Accuracy")
  # plt.xlabel("Epoch #")
  # plt.ylabel("Loss/Accuracy")
  plt.legend(loc="lower left")
  plt.show()

def evaluate_kth_fold(x_train, x_test, y_train, y_test):
  print("[INFO] evaluating network...")
  predIdxs = cnn_model.predict(x_test, batch_size=BS)
  predIdxs = np.argmax(predIdxs, axis=1)

  trainpredIdxs = cnn_model.predict(x_train, batch_size=BS)
  trainpredIdxs = np.argmax(trainpredIdxs, axis=1)

  trainCNNScore=accuracy_score(trainpredIdxs,y_train.argmax(axis=1))*100
  CNNScore=accuracy_score(predIdxs,y_test.argmax(axis=1))*100

  return trainCNNScore, CNNScore

# %%
plot_results(h)

# %%
# Specify the path where you want to save the best model
checkpoint_path = 'best_model.h5'
from keras.callbacks import EarlyStopping

# Create the ModelCheckpoint callback
model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    patience = 2,
    monitor='accuracy',       # Metric to monitor (could also be 'val_accuracy', etc.)
    save_best_only=True,      # Saves only the best model based on the monitored metric
    # save_weights_only=False,  # Set to True to save only the model's weights, not the whole model
    verbose=1                 # Verbosity level: 0 - silent, 1 - progress bar, 2 - one line per epoch.
)
# checkpoint_callback = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, mode='max')
early_stopping_callback = EarlyStopping(monitor='accuracy', patience=10, mode='max', restore_best_weights=True)
my_callbacks = [model_checkpoint, early_stopping_callback]

# %%
INIT_LR = 0.0001
opt = Adam(learning_rate=INIT_LR)
epochs = 100
BS=64

cnn_model = MiniVGGNet(width, height, depth, classes)
# cnn_model = MiniVGGNet(cnn_model)
cnn_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])#, run_eagerly=True)
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      1168
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  dropout (Dropout)           (None, 64, 64, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  batch_normalization (BatchN  (None, 16, 16, 64)       256
#  ormalization)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 4096)              67112960
#
#  dense_1 (Dense)             (None, 1024)              4195328
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 71,337,172
# Trainable params: 71,337,044
# Non-trainable params: 128
# _________________________________________________________________

# %%
# Training
h = cnn_model.fit(x_train, y_train, epochs=epochs, batch_size=BS, callbacks=my_callbacks)
print("Done !!")
# Out:
# Epoch 1/100
# 15/15 [==============================] - ETA: 0s - loss: 4.0333 - accuracy: 0.3229
# Epoch 1: accuracy improved from -inf to 0.32292, saving model to best_model.h5
# 15/15 [==============================] - 21s 453ms/step - loss: 4.0333 - accuracy: 0.3229
# Epoch 2/100
# 15/15 [==============================] - ETA: 0s - loss: 1.7105 - accuracy: 0.3698
# Epoch 2: accuracy improved from 0.32292 to 0.36979, saving model to best_model.h5
# 15/15 [==============================] - 9s 656ms/step - loss: 1.7105 - accuracy: 0.3698
# Epoch 3/100
# 15/15 [==============================] - ETA: 0s - loss: 1.4201 - accuracy: 0.4271
# Epoch 3: accuracy improved from 0.36979 to 0.42708, saving model to best_model.h5
# 15/15 [==============================] - 10s 721ms/step - loss: 1.4201 - accuracy: 0.4271
# Epoch 4/100
# 15/15 [==============================] - ETA: 0s - loss: 1.3263 - accuracy: 0.4229
# Epoch 4: accuracy did not improve from 0.42708
# 15/15 [==============================] - 1s 81ms/step - loss: 1.3263 - accuracy: 0.4229
# Epoch 5/100
# 15/15 [==============================] - ETA: 0s - loss: 1.3024 - accuracy: 0.4083
# Epoch 5: accuracy did not improve from 0.42708
# 15/15 [==============================] - 1s 77ms/step - loss: 1.3024 - accuracy: 0.4083
# Epoch 6/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2583 - accuracy: 0.4542
# Epoch 6: accuracy improved from 0.42708 to 0.45417, saving model to best_model.h5
# 15/15 [==============================] - 8s 593ms/step - loss: 1.2583 - accuracy: 0.4542
# Epoch 7/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2614 - accuracy: 0.4729
# Epoch 7: accuracy improved from 0.45417 to 0.47292, saving model to best_model.h5
# 15/15 [==============================] - 11s 795ms/step - loss: 1.2614 - accuracy: 0.4729
# Epoch 8/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2382 - accuracy: 0.4677
# Epoch 8: accuracy did not improve from 0.47292
# 15/15 [==============================] - 1s 79ms/step - loss: 1.2382 - accuracy: 0.4677
# Epoch 9/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2445 - accuracy: 0.4635
# Epoch 9: accuracy did not improve from 0.47292
# 15/15 [==============================] - 1s 79ms/step - loss: 1.2445 - accuracy: 0.4635
# Epoch 10/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2074 - accuracy: 0.4885
# Epoch 10: accuracy improved from 0.47292 to 0.48854, saving model to best_model.h5
# 15/15 [==============================] - 8s 596ms/step - loss: 1.2074 - accuracy: 0.4885
# Epoch 11/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2345 - accuracy: 0.4708
# Epoch 11: accuracy did not improve from 0.48854
# 15/15 [==============================] - 1s 82ms/step - loss: 1.2345 - accuracy: 0.4708
# Epoch 12/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2059 - accuracy: 0.4729
# Epoch 12: accuracy did not improve from 0.48854
# 15/15 [==============================] - 1s 81ms/step - loss: 1.2059 - accuracy: 0.4729
# Epoch 13/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1981 - accuracy: 0.4771
# Epoch 13: accuracy did not improve from 0.48854
# 15/15 [==============================] - 1s 78ms/step - loss: 1.1981 - accuracy: 0.4771
# Epoch 14/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1922 - accuracy: 0.5083
# Epoch 14: accuracy improved from 0.48854 to 0.50833, saving model to best_model.h5
# 15/15 [==============================] - 7s 501ms/step - loss: 1.1922 - accuracy: 0.5083
# Epoch 15/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1927 - accuracy: 0.4812
# Epoch 15: accuracy did not improve from 0.50833
# 15/15 [==============================] - 1s 95ms/step - loss: 1.1927 - accuracy: 0.4812
# Epoch 16/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1901 - accuracy: 0.5073
# Epoch 16: accuracy did not improve from 0.50833
# 15/15 [==============================] - 1s 89ms/step - loss: 1.1901 - accuracy: 0.5073
# Epoch 17/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1687 - accuracy: 0.5146
# Epoch 17: accuracy improved from 0.50833 to 0.51458, saving model to best_model.h5
# 15/15 [==============================] - 12s 875ms/step - loss: 1.1687 - accuracy: 0.5146
# Epoch 18/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1701 - accuracy: 0.5260
# Epoch 18: accuracy improved from 0.51458 to 0.52604, saving model to best_model.h5
# 15/15 [==============================] - 11s 790ms/step - loss: 1.1701 - accuracy: 0.5260
# Epoch 19/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1402 - accuracy: 0.5083
# Epoch 19: accuracy did not improve from 0.52604
# 15/15 [==============================] - 1s 89ms/step - loss: 1.1402 - accuracy: 0.5083
# Epoch 20/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1760 - accuracy: 0.5281
# Epoch 20: accuracy improved from 0.52604 to 0.52812, saving model to best_model.h5
# 15/15 [==============================] - 11s 750ms/step - loss: 1.1760 - accuracy: 0.5281
# Epoch 21/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1264 - accuracy: 0.5406
# Epoch 21: accuracy improved from 0.52812 to 0.54062, saving model to best_model.h5
# 15/15 [==============================] - 13s 937ms/step - loss: 1.1264 - accuracy: 0.5406
# Epoch 22/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1412 - accuracy: 0.5188
# Epoch 22: accuracy did not improve from 0.54062
# 15/15 [==============================] - 1s 81ms/step - loss: 1.1412 - accuracy: 0.5188
# Epoch 23/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1119 - accuracy: 0.5385
# Epoch 23: accuracy did not improve from 0.54062
# 15/15 [==============================] - 1s 84ms/step - loss: 1.1119 - accuracy: 0.5385
# Epoch 24/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1148 - accuracy: 0.5188
# Epoch 24: accuracy did not improve from 0.54062
# 15/15 [==============================] - 1s 92ms/step - loss: 1.1148 - accuracy: 0.5188
# Epoch 25/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0851 - accuracy: 0.5552
# Epoch 25: accuracy improved from 0.54062 to 0.55521, saving model to best_model.h5
# 15/15 [==============================] - 9s 607ms/step - loss: 1.0851 - accuracy: 0.5552
# Epoch 26/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0517 - accuracy: 0.5604
# Epoch 26: accuracy improved from 0.55521 to 0.56042, saving model to best_model.h5
# 15/15 [==============================] - 10s 698ms/step - loss: 1.0517 - accuracy: 0.5604
# Epoch 27/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0916 - accuracy: 0.5333
# Epoch 27: accuracy did not improve from 0.56042
# 15/15 [==============================] - 1s 83ms/step - loss: 1.0916 - accuracy: 0.5333
# Epoch 28/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0655 - accuracy: 0.5396
# Epoch 28: accuracy did not improve from 0.56042
# 15/15 [==============================] - 1s 79ms/step - loss: 1.0655 - accuracy: 0.5396
# Epoch 29/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0399 - accuracy: 0.5771
# Epoch 29: accuracy improved from 0.56042 to 0.57708, saving model to best_model.h5
# 15/15 [==============================] - 8s 584ms/step - loss: 1.0399 - accuracy: 0.5771
# Epoch 30/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0390 - accuracy: 0.5385
# Epoch 30: accuracy did not improve from 0.57708
# 15/15 [==============================] - 1s 83ms/step - loss: 1.0390 - accuracy: 0.5385
# Epoch 31/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0610 - accuracy: 0.5490
# Epoch 31: accuracy did not improve from 0.57708
# 15/15 [==============================] - 1s 80ms/step - loss: 1.0610 - accuracy: 0.5490
# Epoch 32/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0641 - accuracy: 0.5615
# Epoch 32: accuracy did not improve from 0.57708
# 15/15 [==============================] - 1s 79ms/step - loss: 1.0641 - accuracy: 0.5615
# Epoch 33/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0120 - accuracy: 0.5813
# Epoch 33: accuracy improved from 0.57708 to 0.58125, saving model to best_model.h5
# 15/15 [==============================] - 8s 558ms/step - loss: 1.0120 - accuracy: 0.5813
# Epoch 34/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0012 - accuracy: 0.5865
# Epoch 34: accuracy improved from 0.58125 to 0.58646, saving model to best_model.h5
# 15/15 [==============================] - 15s 1s/step - loss: 1.0012 - accuracy: 0.5865
# Epoch 35/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0139 - accuracy: 0.5740
# Epoch 35: accuracy did not improve from 0.58646
# 15/15 [==============================] - 1s 83ms/step - loss: 1.0139 - accuracy: 0.5740
# Epoch 36/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0017 - accuracy: 0.5896
# Epoch 36: accuracy improved from 0.58646 to 0.58958, saving model to best_model.h5
# 15/15 [==============================] - 9s 640ms/step - loss: 1.0017 - accuracy: 0.5896
# Epoch 37/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9711 - accuracy: 0.5802
# Epoch 37: accuracy did not improve from 0.58958
# 15/15 [==============================] - 1s 83ms/step - loss: 0.9711 - accuracy: 0.5802
# Epoch 38/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9796 - accuracy: 0.5896
# Epoch 38: accuracy did not improve from 0.58958
# 15/15 [==============================] - 1s 81ms/step - loss: 0.9796 - accuracy: 0.5896
# Epoch 39/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9840 - accuracy: 0.5833
# Epoch 39: accuracy did not improve from 0.58958
# 15/15 [==============================] - 1s 80ms/step - loss: 0.9840 - accuracy: 0.5833
# Epoch 40/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9385 - accuracy: 0.5958
# Epoch 40: accuracy improved from 0.58958 to 0.59583, saving model to best_model.h5
# 15/15 [==============================] - 9s 604ms/step - loss: 0.9385 - accuracy: 0.5958
# Epoch 41/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8887 - accuracy: 0.6250
# Epoch 41: accuracy improved from 0.59583 to 0.62500, saving model to best_model.h5
# 15/15 [==============================] - 14s 1s/step - loss: 0.8887 - accuracy: 0.6250
# Epoch 42/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9263 - accuracy: 0.6094
# Epoch 42: accuracy did not improve from 0.62500
# 15/15 [==============================] - 1s 83ms/step - loss: 0.9263 - accuracy: 0.6094
# Epoch 43/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9225 - accuracy: 0.6094
# Epoch 43: accuracy did not improve from 0.62500
# 15/15 [==============================] - 1s 79ms/step - loss: 0.9225 - accuracy: 0.6094
# Epoch 44/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9243 - accuracy: 0.6094
# Epoch 44: accuracy did not improve from 0.62500
# 15/15 [==============================] - 1s 79ms/step - loss: 0.9243 - accuracy: 0.6094
# Epoch 45/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8986 - accuracy: 0.6198
# Epoch 45: accuracy did not improve from 0.62500
# 15/15 [==============================] - 1s 80ms/step - loss: 0.8986 - accuracy: 0.6198
# Epoch 46/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8757 - accuracy: 0.6292
# Epoch 46: accuracy improved from 0.62500 to 0.62917, saving model to best_model.h5
# 15/15 [==============================] - 12s 875ms/step - loss: 0.8757 - accuracy: 0.6292
# Epoch 47/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8513 - accuracy: 0.6385
# Epoch 47: accuracy improved from 0.62917 to 0.63854, saving model to best_model.h5
# 15/15 [==============================] - 8s 533ms/step - loss: 0.8513 - accuracy: 0.6385
# Epoch 48/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8097 - accuracy: 0.6729
# Epoch 48: accuracy improved from 0.63854 to 0.67292, saving model to best_model.h5
# 15/15 [==============================] - 12s 864ms/step - loss: 0.8097 - accuracy: 0.6729
# Epoch 49/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7910 - accuracy: 0.6656
# Epoch 49: accuracy did not improve from 0.67292
# 15/15 [==============================] - 1s 86ms/step - loss: 0.7910 - accuracy: 0.6656
# Epoch 50/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7801 - accuracy: 0.6792
# Epoch 50: accuracy improved from 0.67292 to 0.67917, saving model to best_model.h5
# 15/15 [==============================] - 14s 1s/step - loss: 0.7801 - accuracy: 0.6792
# Epoch 51/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7847 - accuracy: 0.6677
# Epoch 51: accuracy did not improve from 0.67917
# 15/15 [==============================] - 1s 83ms/step - loss: 0.7847 - accuracy: 0.6677
# Epoch 52/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7721 - accuracy: 0.6667
# Epoch 52: accuracy did not improve from 0.67917
# 15/15 [==============================] - 1s 79ms/step - loss: 0.7721 - accuracy: 0.6667
# Epoch 53/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7494 - accuracy: 0.6896
# Epoch 53: accuracy improved from 0.67917 to 0.68958, saving model to best_model.h5
# 15/15 [==============================] - 8s 594ms/step - loss: 0.7494 - accuracy: 0.6896
# Epoch 54/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7352 - accuracy: 0.6812
# Epoch 54: accuracy did not improve from 0.68958
# 15/15 [==============================] - 1s 82ms/step - loss: 0.7352 - accuracy: 0.6812
# Epoch 55/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7108 - accuracy: 0.6958
# Epoch 55: accuracy improved from 0.68958 to 0.69583, saving model to best_model.h5
# 15/15 [==============================] - 7s 484ms/step - loss: 0.7108 - accuracy: 0.6958
# Epoch 56/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7146 - accuracy: 0.7042
# Epoch 56: accuracy improved from 0.69583 to 0.70417, saving model to best_model.h5
# 15/15 [==============================] - 14s 1s/step - loss: 0.7146 - accuracy: 0.7042
# Epoch 57/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6618 - accuracy: 0.7365
# Epoch 57: accuracy improved from 0.70417 to 0.73646, saving model to best_model.h5
# 15/15 [==============================] - 14s 1s/step - loss: 0.6618 - accuracy: 0.7365
# Epoch 58/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6831 - accuracy: 0.7208
# Epoch 58: accuracy did not improve from 0.73646
# 15/15 [==============================] - 1s 83ms/step - loss: 0.6831 - accuracy: 0.7208
# Epoch 59/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.7417
# Epoch 59: accuracy improved from 0.73646 to 0.74167, saving model to best_model.h5
# 15/15 [==============================] - 10s 688ms/step - loss: 0.6300 - accuracy: 0.7417
# Epoch 60/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.7594
# Epoch 60: accuracy improved from 0.74167 to 0.75937, saving model to best_model.h5
# 15/15 [==============================] - 10s 732ms/step - loss: 0.6136 - accuracy: 0.7594
# Epoch 61/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6055 - accuracy: 0.7312
# Epoch 61: accuracy did not improve from 0.75937
# 15/15 [==============================] - 1s 93ms/step - loss: 0.6055 - accuracy: 0.7312
# Epoch 62/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5577 - accuracy: 0.7823
# Epoch 62: accuracy improved from 0.75937 to 0.78229, saving model to best_model.h5
# 15/15 [==============================] - 8s 562ms/step - loss: 0.5577 - accuracy: 0.7823
# Epoch 63/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7781
# Epoch 63: accuracy did not improve from 0.78229
# 15/15 [==============================] - 1s 82ms/step - loss: 0.5443 - accuracy: 0.7781
# Epoch 64/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5601 - accuracy: 0.7708
# Epoch 64: accuracy did not improve from 0.78229
# 15/15 [==============================] - 1s 79ms/step - loss: 0.5601 - accuracy: 0.7708
# Epoch 65/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5224 - accuracy: 0.7760
# Epoch 65: accuracy did not improve from 0.78229
# 15/15 [==============================] - 1s 80ms/step - loss: 0.5224 - accuracy: 0.7760
# Epoch 66/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5136 - accuracy: 0.7906
# Epoch 66: accuracy improved from 0.78229 to 0.79062, saving model to best_model.h5
# 15/15 [==============================] - 8s 592ms/step - loss: 0.5136 - accuracy: 0.7906
# Epoch 67/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5061 - accuracy: 0.8083
# Epoch 67: accuracy improved from 0.79062 to 0.80833, saving model to best_model.h5
# 15/15 [==============================] - 10s 721ms/step - loss: 0.5061 - accuracy: 0.8083
# Epoch 68/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4879 - accuracy: 0.8094
# Epoch 68: accuracy improved from 0.80833 to 0.80937, saving model to best_model.h5
# 15/15 [==============================] - 13s 943ms/step - loss: 0.4879 - accuracy: 0.8094
# Epoch 69/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.7979
# Epoch 69: accuracy did not improve from 0.80937
# 15/15 [==============================] - 1s 83ms/step - loss: 0.5161 - accuracy: 0.7979
# Epoch 70/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4765 - accuracy: 0.8167
# Epoch 70: accuracy improved from 0.80937 to 0.81667, saving model to best_model.h5
# 15/15 [==============================] - 5s 374ms/step - loss: 0.4765 - accuracy: 0.8167
# Epoch 71/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4393 - accuracy: 0.8302
# Epoch 71: accuracy improved from 0.81667 to 0.83021, saving model to best_model.h5
# 15/15 [==============================] - 7s 477ms/step - loss: 0.4393 - accuracy: 0.8302
# Epoch 72/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.8156
# Epoch 72: accuracy did not improve from 0.83021
# 15/15 [==============================] - 1s 83ms/step - loss: 0.4621 - accuracy: 0.8156
# Epoch 73/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.8115
# Epoch 73: accuracy did not improve from 0.83021
# 15/15 [==============================] - 1s 80ms/step - loss: 0.4585 - accuracy: 0.8115
# Epoch 74/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4281 - accuracy: 0.8333
# Epoch 74: accuracy improved from 0.83021 to 0.83333, saving model to best_model.h5
# 15/15 [==============================] - 8s 537ms/step - loss: 0.4281 - accuracy: 0.8333
# Epoch 75/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4089 - accuracy: 0.8406
# Epoch 75: accuracy improved from 0.83333 to 0.84062, saving model to best_model.h5
# 15/15 [==============================] - 11s 760ms/step - loss: 0.4089 - accuracy: 0.8406
# Epoch 76/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8615
# Epoch 76: accuracy improved from 0.84062 to 0.86146, saving model to best_model.h5
# 15/15 [==============================] - 11s 755ms/step - loss: 0.3753 - accuracy: 0.8615
# Epoch 77/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8625
# Epoch 77: accuracy improved from 0.86146 to 0.86250, saving model to best_model.h5
# 15/15 [==============================] - 9s 615ms/step - loss: 0.3752 - accuracy: 0.8625
# Epoch 78/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.8594
# Epoch 78: accuracy did not improve from 0.86250
# 15/15 [==============================] - 1s 82ms/step - loss: 0.3547 - accuracy: 0.8594
# Epoch 79/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3405 - accuracy: 0.8719
# Epoch 79: accuracy improved from 0.86250 to 0.87187, saving model to best_model.h5
# 15/15 [==============================] - 9s 655ms/step - loss: 0.3405 - accuracy: 0.8719
# Epoch 80/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8833
# Epoch 80: accuracy improved from 0.87187 to 0.88333, saving model to best_model.h5
# 15/15 [==============================] - 12s 824ms/step - loss: 0.3125 - accuracy: 0.8833
# Epoch 81/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.8823
# Epoch 81: accuracy did not improve from 0.88333
# 15/15 [==============================] - 1s 90ms/step - loss: 0.3020 - accuracy: 0.8823
# Epoch 82/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2974 - accuracy: 0.8885
# Epoch 82: accuracy improved from 0.88333 to 0.88854, saving model to best_model.h5
# 15/15 [==============================] - 8s 585ms/step - loss: 0.2974 - accuracy: 0.8885
# Epoch 83/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.8969
# Epoch 83: accuracy improved from 0.88854 to 0.89688, saving model to best_model.h5
# 15/15 [==============================] - 7s 483ms/step - loss: 0.2770 - accuracy: 0.8969
# Epoch 84/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.8917
# Epoch 84: accuracy did not improve from 0.89688
# 15/15 [==============================] - 1s 84ms/step - loss: 0.2931 - accuracy: 0.8917
# Epoch 85/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9021
# Epoch 85: accuracy improved from 0.89688 to 0.90208, saving model to best_model.h5
# 15/15 [==============================] - 8s 587ms/step - loss: 0.2666 - accuracy: 0.9021
# Epoch 86/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.8979
# Epoch 86: accuracy did not improve from 0.90208
# 15/15 [==============================] - 2s 99ms/step - loss: 0.2689 - accuracy: 0.8979
# Epoch 87/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.9156
# Epoch 87: accuracy improved from 0.90208 to 0.91562, saving model to best_model.h5
# 15/15 [==============================] - 8s 579ms/step - loss: 0.2464 - accuracy: 0.9156
# Epoch 88/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.9115
# Epoch 88: accuracy did not improve from 0.91562
# 15/15 [==============================] - 1s 83ms/step - loss: 0.2368 - accuracy: 0.9115
# Epoch 89/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2281 - accuracy: 0.9208
# Epoch 89: accuracy improved from 0.91562 to 0.92083, saving model to best_model.h5
# 15/15 [==============================] - 14s 972ms/step - loss: 0.2281 - accuracy: 0.9208
# Epoch 90/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2383 - accuracy: 0.9094
# Epoch 90: accuracy did not improve from 0.92083
# 15/15 [==============================] - 1s 81ms/step - loss: 0.2383 - accuracy: 0.9094
# Epoch 91/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9271
# Epoch 91: accuracy improved from 0.92083 to 0.92708, saving model to best_model.h5
# 15/15 [==============================] - 9s 646ms/step - loss: 0.2195 - accuracy: 0.9271
# Epoch 92/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1927 - accuracy: 0.9323
# Epoch 92: accuracy improved from 0.92708 to 0.93229, saving model to best_model.h5
# 15/15 [==============================] - 10s 672ms/step - loss: 0.1927 - accuracy: 0.9323
# Epoch 93/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9323
# Epoch 93: accuracy did not improve from 0.93229
# 15/15 [==============================] - 1s 82ms/step - loss: 0.1972 - accuracy: 0.9323
# Epoch 94/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9187
# Epoch 94: accuracy did not improve from 0.93229
# 15/15 [==============================] - 1s 79ms/step - loss: 0.1976 - accuracy: 0.9187
# Epoch 95/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9281
# Epoch 95: accuracy did not improve from 0.93229
# 15/15 [==============================] - 1s 80ms/step - loss: 0.1946 - accuracy: 0.9281
# Epoch 96/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9271
# Epoch 96: accuracy did not improve from 0.93229
# 15/15 [==============================] - 1s 80ms/step - loss: 0.2033 - accuracy: 0.9271
# Epoch 97/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9344
# Epoch 97: accuracy improved from 0.93229 to 0.93437, saving model to best_model.h5
# 15/15 [==============================] - 8s 592ms/step - loss: 0.1772 - accuracy: 0.9344
# Epoch 98/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9281
# Epoch 98: accuracy did not improve from 0.93437
# 15/15 [==============================] - 1s 84ms/step - loss: 0.1882 - accuracy: 0.9281
# Epoch 99/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9615
# Epoch 99: accuracy improved from 0.93437 to 0.96146, saving model to best_model.h5
# 15/15 [==============================] - 10s 684ms/step - loss: 0.1318 - accuracy: 0.9615
# Epoch 100/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9542
# Epoch 100: accuracy did not improve from 0.96146
# 15/15 [==============================] - 1s 80ms/step - loss: 0.1334 - accuracy: 0.9542
# Done !!

# %%
path

# %%
import tensorflow as tf

from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from keras.models import Model
from matplotlib import pyplot
from numpy import expand_dims
# load the model
# model = VGG16()
# filename='/content/drive/MyDrive/ML-Datasets/Messidore/Messidor_dataset_without_clahe/normal/20051205_60119_0400_PP.tif.png'
def feature_map_visuals(model, filename, idxLayer):
    target_size=(256,256)
    print(model)
    # redefine model to output right after the first hidden layer
    model = Model(inputs=model.inputs, outputs=model.layers[idxLayer].output)
    print(model.summary())
    # load the image with the required shape
    img = load_img(filename, target_size=target_size)
    # convert the image to an array
    img = img_to_array(img)
    # expand dimensions so that it represents a single 'sample'
    img = expand_dims(img, axis=0)
    # prepare the image (e.g. scale pixel values for the vgg)
    # img = preprocess_input(img)
    # get feature map for first hidden layer
    feature_maps = model.predict(img)
    # plot all 64 maps in an 8x8 squares
    square = 8
    ix = 1
    for _ in range(square):
        for _ in range(square):
            # specify subplot and turn of axis
            ax = pyplot.subplot(square, square, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            # plot filter channel in grayscale
            pyplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
            ix += 1
        # show the figure
        pyplot.show()

# %%
print(path[20])
filename = path[20]
feature_map_visuals(cnn_model, filename, 7)
# Out:
# /content/drive/MyDrive/ML-Datasets/Retinopathy/Messidor_dataset_without_clahe/normal/20051020_56791_0100_PP.tif.png
# <keras.engine.sequential.Sequential object at 0x7e8ebd3cb700>
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      1168
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  dropout (Dropout)           (None, 64, 64, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        18496
#
# =================================================================
# Total params: 24,528
# Trainable params: 24,528
# Non-trainable params: 0
# _________________________________________________________________
# None
# 1/1 [==============================] - 0s 99ms/step

# %%
trainCNNScore, CNNScore = evaluate_kth_fold(x_train, x_test, y_train, y_test)

print("\nTrainig Accuracy Score:-",trainCNNScore)
print("\nTesting Accuracy Score:-",CNNScore)
print("\nTraning Graph:- \n ")

plot_results(h)
# Out:
# [INFO] evaluating network...
# 4/4 [==============================] - 1s 135ms/step
# 15/15 [==============================] - 1s 33ms/step
#
# Trainig Accuracy Score:- 90.20833333333333
#
# Testing Accuracy Score:- 48.333333333333336
#
# Traning Graph:-

# %%
width,height=256,256
depth = 3
input_shape = (height, width, depth)

classes = 4
depth = 3
INIT_LR = 1e-3
EPOCHS = 100
BS=32

from keras.optimizers import Nadam, SGD, Adam
from sklearn.model_selection import StratifiedKFold

h = []
Kfold = StratifiedKFold(n_splits=8)
for train, test in Kfold.split(x_train, y_train.argmax(axis=1)):
  cnn_model = Sequential()
  # opt = Nadam(learning_rate=INIT_LR)
  # opt = adam_v1(learning_rate=INIT_LR)
  opt = Adam(learning_rate=INIT_LR)

  # cnn_model = MiniVGGNet(width, height, depth, classes)
  cnn_model = MiniVGGNetv01(cnn_model)
  cnn_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])#, run_eagerly=True)
  # cnn_model.summary()
  h = cnn_model.fit(x_train[train], y_train[train], epochs=EPOCHS, batch_size=BS, callbacks=my_callbacks)
  print("Done !!")

  trainCNNScore, CNNScore = evaluate_kth_fold(x_train[train], x_test, y_train[train], y_test)

  print("\nTrainig Accuracy Score:-",trainCNNScore)
  print("\nTesting Accuracy Score:-",CNNScore)
  print("\nTraning Graph:- \n ")

plot_results(h)

  # cnn_model = MiniVGGNetv01(model)
# opt = gradient_descent_legacy.SGD (learning_rate = INIT_LR)
# cnn_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'], run_eagerly=True)
# cnn_model.summary()
# Out:
# Epoch 1/100
# 27/27 [==============================] - ETA: 0s - loss: 2706.5725 - accuracy: 0.3456
# Epoch 1: accuracy improved from -inf to 0.34556, saving model to best_model.h5

# %%
plot_results(h)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-98d22618098a> in <cell line: 1>()
# ----> 1 plot_results(h)
#
# <ipython-input-29-8363694c2783> in plot_results(h)
#      19   plt.figure()
#      20   plt.plot(np.arange(0, N), h.history["loss"], label="train_loss")
# ---> 21   plt.plot(np.arange(0, N), h.history["val_loss"], label="val_loss")
#      22   plt.title("Training Loss vs. validation Loss")
#      23   plt.xlabel("Epoch #")
#
# KeyError: 'val_loss'

# %%
# !pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.10.1)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_pred = cnn_model(x_test)
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
cm
classes = ['normal', 'mild', 'moderate', 'severe']
plot_confusion_matrix(cm, classes=classes, normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues)

# %%
extractCNN = Model(cnn_model.inputs, cnn_model.layers[-3].output)

#del(data)
#del(labels)
feat_trainCNN  = extractCNN.predict(x_train)
feat_testCNN = extractCNN.predict(x_test)

print(feat_trainCNN.shape)
# Out:
# 30/30 [==============================] - 1s 24ms/step
# 8/8 [==============================] - 0s 14ms/step
# (960, 1024)

# %%
from sklearn.decomposition import NMF

nmf = NMF(n_components=100)
print(np.min(feat_trainCNN))
nmfBasis = nmf.fit(feat_trainCNN)
# Out:
# 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
feat_trainCNN = nmfBasis
from sklearn.svm import SVC

svm = SVC(kernel='linear')
svm.fit(feat_trainCNN,np.argmax(y_train,axis=1))

TrainSVMScoreCNN=svm.score(feat_trainCNN,np.argmax(y_train,axis=1))*100
print("SVM Training Accuracy Score:-",TrainSVMScoreCNN)

TestSVMScoreCNN=svm.score(feat_testCNN,np.argmax(y_test,axis=1))*100
print("\nSVM Testing Accuracy Score:-",TestSVMScoreCNN)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-fccd338bbc21> in <cell line: 5>()
#       3
#       4 svm = SVC(kernel='linear')
# ----> 5 svm.fit(feat_trainCNN,np.argmax(y_train,axis=1))
#       6
#       7 TrainSVMScoreCNN=svm.score(feat_trainCNN,np.argmax(y_train,axis=1))*100
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     190             check_consistent_length(X, y)
#     191         else:
# --> 192             X, y = self._validate_data(
#     193                 X,
#     194                 y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# TypeError: float() argument must be a string or a real number, not 'NMF'

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=0)
clf = clf.fit(feat_trainCNN,np.argmax(y_train,axis=1))

TrainDecisionScoreCNN=clf.score(feat_trainCNN,np.argmax(y_train,axis=1))*100
print("Decision Tree Training Accuracy Score:-",TrainDecisionScoreCNN)


TestDecisionScoreCNN=clf.score(feat_testCNN,np.argmax(y_test,axis=1))*100
print("\nDecision Tree Testing Accuracy Score:-",TestDecisionScoreCNN)
# Out:
# Decision Tree Training Accuracy Score:- 100.0
#
# Decision Tree Testing Accuracy Score:- 89.54545454545455

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(feat_trainCNN,np.argmax(y_train,axis=1))

TrainKNNScoreCNN=knn.score(feat_trainCNN,np.argmax(y_train,axis=1))*100
print("KNN Training Accuracy Score:-",TrainKNNScoreCNN)

TestKNNScoreCNN=knn.score(feat_testCNN,np.argmax(y_test,axis=1))*100
print("\nKNN Testing Accuracy Score:-",TestKNNScoreCNN)
# Out:
# KNN Training Accuracy Score:- 98.51767388825542
#
# KNN Testing Accuracy Score:- 97.27272727272728

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(feat_trainCNN,np.argmax(y_train,axis=1))

TrainNBScoreCNN=gnb.score(feat_trainCNN,np.argmax(y_train,axis=1))*100
print("\nGaussianNaive Bayes Training Accuracy Score:-",TrainNBScoreCNN)

TestNBScoreCNN=gnb.score(feat_testCNN,np.argmax(y_test,axis=1))*100
print("\nGaussianNaive Bayes Testing Accuracy Score:-",TestNBScoreCNN)
# Out:
# GaussianNaive Bayes Training Accuracy Score:- 82.09806157354618
#
# GaussianNaive Bayes Testing Accuracy Score:- 69.54545454545455
